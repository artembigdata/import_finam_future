# %% [markdown]
# https://www.youtube.com/watch?v=OR8W7MJGGGo - пример с YouTube

# %%
from selenium import webdriver
from selenium.webdriver.support.select import Select
import time
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
#from selenium import Webdriver
import json

# %% [markdown]
# https://www.finam.ru/profile/moex-akcii/gazprom/export/ - ссылка на сайт финам/экспорт котировок.

# %%
browser = webdriver.Chrome(
executable_path='/Users/artemislamowicloud.com/Documents/Jupiter_Notebook/управление браузером/chromedriver')

# %%
browser = webdriver.Chrome()
browser.maximize_window()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/.conda/envs/import_finam_future/lib/python3.10/site-packages/selenium/webdriver/common/service.py:72, in Service.start(self)
#      71     cmd.extend(self.command_line_args())
# ---> 72     self.process = subprocess.Popen(cmd, env=self.env,
#      73                                     close_fds=platform.system() != 'Windows',
#      74                                     stdout=self.log_file,
#      75                                     stderr=self.log_file,
#      76                                     stdin=PIPE)
#      77 except TypeError:
#
# ...

# %%
#  открываю ссылку на сайт финам экспорт котировок
browser.get('https://www.finam.ru/profile/moex-akcii/gazprom/export/')

# %% [markdown]
# нажимаю на кнопку, чтобы появился выпадающий список
# ![image.png](attachment:image.png)

# %%
# пытаюсь нажать на кнопку выбор рынка
from webdriver_manager.core import driver

future = browser.find_element_by_class_name('finam-ui-quote-selector-arrow')
future.click()
#Select.select_by_value(value='14')

# %% [markdown]
# Хочу выбрать "МосБиржа фьючерсы" из выпадающего списка и нажать. Но не находит и не работает
# ![image.png](attachment:image.png)

# %%
Select(futures = browser.find_element(By.__class__('finam-ui-dropdown-list'))).select_by_visible_text("Мосбиржа фьючерсы")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [87], in <cell line: 1>()
# ----> 1 Select(futures = browser.find_element(By.__class__('finam-ui-dropdown-list'))).select_by_visible_text("Мосбиржа фьючерсы")
#
# File ~/.conda/envs/import_finam_future/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:976, in WebDriver.find_element(self, by, value)
#     974         by = By.CSS_SELECTOR
#     975         value = '[name="%s"]' % value
# --> 976 return self.execute(Command.FIND_ELEMENT, {
#     977     'using': by,
#     978     'value': value})['value']
#
# File ~/.conda/envs/import_finam_future/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:319, in WebDriver.execute(self, driver_command, params)
#     316         params['sessionId'] = self.session_id
#     318 params = self._wrap_value(params)
# ...

# %%
print(futures)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="f28890e4c6fb974f92f16fc71bd270c9", element="31f5e205-83fa-45c6-8ffe-c422f510edfc")>
