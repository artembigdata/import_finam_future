# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Пытаюсь-найти-выпадающий-список-с-вводом-даты." data-toc-modified-id="Пытаюсь-найти-выпадающий-список-с-вводом-даты.-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Пытаюсь найти выпадающий список с вводом даты.</a></span></li></ul></div>

# %%
from selenium import webdriver

# %%
from selenium import webdriver

# %%
import time

# %%
#from selenium import By

# %%
import json

# %%
from selenium.webdriver.support.ui import Select

# %%
from webdriver_manager.chrome import ChromeDriverManager
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 from webdriver_manager.chrome import ChromeDriverManager
#
# ModuleNotFoundError: No module named 'webdriver_manager'

# %%
from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome(
executable_path='/Users/artemislamowicloud.com/Documents/Jupiter_Notebook/управление браузером/chromedriver')
driver.get('https://www.finam.ru/profile/mosbirzha-fyuchersy/rts/export/?market=14&em=17455&token=&code=RTS&apply=0&df=1&mf=9&yf=2021&from=01.10.2021&dt=2&mt=9&yt=2022&to=02.10.2022&p=7&f=RTS_211001_221002&e=.csv&cn=RTS&dtf=4&tmf=1&MSOR=1&mstime=on&mstimever=1&sep=1&sep2=1&datf=1&at=1')

# %% [markdown]
# # Пытаюсь найти выпадающий список с вводом даты.
#  ![image.png](attachment:image.png)

# %%
b = driver.find_element_by_xpath("//*[@id='issuer-profile-export-from']")

# %%
#from selenium.webdriver.common.by import By

#button_login = driver.find_element(By.XPATH, "//*[@id='issuer-profile-header']/div[1]/div[1]")

# %% [markdown]
# пытаюсь ввести дату в поле

# %%
b.send_keys('1.10.2021')

# %%
#from selenium.webdriver.common.by import By

#button_login = driver.find_element(By.XPATH, "//*[@id='issuer-profile-header']/div[1]/div[1]")

# %%
#button_login1 = driver.find_element(By.LINK_TEXT, input()"[value= 'МосБиржа фьючерсы']" #"[/html/body/div[15]/div/ul/li[5]/a")

# %%
#button_login = driver.find_element(By.XPATH, "//button[text()='Войти']")
#button_login.click()
